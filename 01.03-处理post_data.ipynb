# %%
import pandas as pd

# %%
import jieba
import jieba.posseg as pseg

# %%
df = pd.read_csv('data/post_data.txt', sep='\t')
df.head()
# Out:
#     id title                                           content
# 0    3   NaN                     给老婆过了一个简单的生日，happy birthday 。
# 1   15   NaN                                         敢从上面滑下来么？
# 2   23   NaN                                             第一次冰钓
# 3   39   NaN                                如果有一天失业了～～那我还能混口饭吃
# 4  109   NaN   —— 儿 童 节 —— 国际儿童节定于每年的6月1日。为了悼念1942年6月10日的利迪策...

# %%
words = pseg.cut("如果有一天失业了～～那我还能混口饭吃")
for word, flag in words:
    print('%s %s' % (word, flag))
# Out:
# 如果 c
# 有 v
# 一天 m
# 失业 n
# 了 ul
# ～ x
# ～ x
# 那 r
# 我 r
# 还 d
# 能 v
# 混口饭吃 i

# %%
len(df)
# Out:
# 83630

# %%
# Out:
#            id       title                                           content
# 0           3         NaN                     给老婆过了一个简单的生日，happy birthday 。
# 1          15         NaN                                         敢从上面滑下来么？
# 2          23         NaN                                             第一次冰钓
# 3          39         NaN                                如果有一天失业了～～那我还能混口饭吃
# 4         109         NaN   —— 儿 童 节 —— 国际儿童节定于每年的6月1日。为了悼念1942年6月10日的利迪策...
# 5         155         NaN   五月榴花妖艳烘，绿杨带雨垂垂重，五色新丝缠角粽。金盘送，生绡画扇盘双凤。 正是浴兰时节动，...
# 6         159         NaN   ‍ ‍ ‍ ‍ —— 父 亲 节 —— 父亲节， 顾名思义是感恩父亲的节日。 约始于二十世...
# 7         163         NaN   —— 建 军 节 —— 每年的八月一日是中国 人民解放军建军纪念日，因此也叫“ 八一 ”建...
# 8         173         NaN   万事销身外，生涯在镜中。 惟将两鬓雪，明日对秋风。 ——（唐）李益《 立秋前一日览镜 》 ...
# 9         227         NaN                 匆匆忙忙两天赶回来参加老姐婚礼，刚刚返回帝都，明天继续各种bug！
# 10        237         NaN   绛节飘飖宫国来，中元朝拜上清回。 羊权须得金条脱，温峤终虚玉镜台。 曾省惊眠闻雨过，不知迷...
# ...
